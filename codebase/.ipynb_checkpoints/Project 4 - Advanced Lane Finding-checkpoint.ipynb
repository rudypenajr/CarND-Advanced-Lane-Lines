# %% [markdown]
# ## Project 4: Advance Lane Finding

# %% [markdown]
# ### Step 2: Compute Camera Calibration Matrix and Distortion Coefficents given a set of chessboard images.

# %%
from Calibration import Calibration
calibration = Calibration()
# Out:
# ######################
# No Saved Models. Finding Corners Now.
# ######################
# hello
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-36d5f162823b> in <module>()
#       1 from Calibration import Calibration
# ----> 2 calibration = Calibration()
#
# /Users/rudypena/Sites/carnd/CarND-Advanced-Lane-Lines/codebase/Calibration.py in __init__(self)
#      22             # self.find_corners()
#      23
# ---> 24         ret, self.mtx, self.dist, _, self._ = cv2.calibrateCamera(self.objpoints, self.imgpoints, self.shape, None, None)
#      25
#      26         print("######################")
#
# error: /Users/jenkins/miniconda/1/x64/conda-bld/work/opencv-3.1.0/modules/calib3d/src/calibration.cpp:3314: error: (-215) nimages > 0 in function calibrateCamera
